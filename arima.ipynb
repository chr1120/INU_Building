# %%
# https://blog.naver.com/chromatic_365/222657670527
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pymysql
import matplotlib as mpl

# mysql db 연동
db = pymysql.connect(host='127.0.0.1',password='gkftndlTek!!',user='root',db='tp',charset='utf8', 
    cursorclass=pymysql.cursors.DictCursor)

cursor = db.cursor()

query = "select DATETIME, FM,`FM_[0]`,`FM_[1]` from wholeData where DATETIME between '2014-01-01 00:00:00' and '2022-05-15 23:00:00'"
cursor.execute(query)
db_export = cursor.fetchall()

tp=pd.DataFrame(db_export)
#db_result_df = db_result_df.drop([db_result_df.columns[0]], axis=1) # 중복 index열 삭제

tp.index=tp['DATETIME']
tp.set_index('DATETIME', inplace=True)
tp.plot()
plt.show()

# %%
# https://blog.naver.com/chromatic_365/222657670527
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pymysql
import matplotlib as mpl

# mysql db 연동
db = pymysql.connect(host='127.0.0.1',password='gkftndlTek!!',user='root',db='tp',charset='utf8', 
    cursorclass=pymysql.cursors.DictCursor)

cursor = db.cursor()

query = "select DATETIME, FM,`FM_[0]`,`FM_[1]`,`FM_[2]`,`FM_[3]`,`FM_[4]`,`FM_[5]`,`FM_[6]`,`FM_[7]`,`FM_[8]`,`FM_[9]`,`FM_[10]`,`FM_[11]`,`FM_[12]`,`FM_[13]`,`FM_[14]`,`FM_[15]`,`FM_[16]`,`FM_[17]`,`FM_[18]` from wholeData where DATETIME between '2014-01-01 00:00:00' and '2022-05-15 23:00:00'"
cursor.execute(query)
db_export = cursor.fetchall()

tp=pd.DataFrame(db_export)
#db_result_df = db_result_df.drop([db_result_df.columns[0]], axis=1) # 중복 index열 삭제

tp.index=tp['DATETIME']
tp.set_index('DATETIME', inplace=True)
tp.plot()
plt.show()

# %%
# https://blog.naver.com/chromatic_365/222657670527
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pymysql
import matplotlib as mpl

# mysql db 연동
db = pymysql.connect(host='127.0.0.1',password='gkftndlTek!!',user='root',db='tp',charset='utf8', 
    cursorclass=pymysql.cursors.DictCursor)

cursor = db.cursor()

query = "select DATETIME, PU1 from wholeData where DATETIME between '2014-01-01 00:00:00' and '2022-05-15 23:00:00'"
cursor.execute(query)
db_export = cursor.fetchall()

tp=pd.DataFrame(db_export)
#db_result_df = db_result_df.drop([db_result_df.columns[0]], axis=1) # 중복 index열 삭제

tp.index=tp['DATETIME']
tp.set_index('DATETIME', inplace=True)
tp.plot()
plt.show()

# %%
# https://blog.naver.com/chromatic_365/222657670527
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pymysql
import matplotlib as mpl

# mysql db 연동
db = pymysql.connect(host='127.0.0.1',password='gkftndlTek!!',user='root',db='tp',charset='utf8', 
    cursorclass=pymysql.cursors.DictCursor)

cursor = db.cursor()

query = "select DATETIME, PU2 from wholeData where DATETIME between '2014-01-01 00:00:00' and '2022-05-15 23:00:00'"
cursor.execute(query)
db_export = cursor.fetchall()

tp=pd.DataFrame(db_export)
#db_result_df = db_result_df.drop([db_result_df.columns[0]], axis=1) # 중복 index열 삭제

tp.index=tp['DATETIME']
tp.set_index('DATETIME', inplace=True)
tp.plot()
plt.show()

# %%
# https://blog.naver.com/chromatic_365/222657670527
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pymysql
import matplotlib as mpl

# mysql db 연동
db = pymysql.connect(host='127.0.0.1',password='gkftndlTek!!',user='root',db='tp',charset='utf8', 
    cursorclass=pymysql.cursors.DictCursor)

cursor = db.cursor()

query = "select DATETIME, TE1 from wholeData where DATETIME between '2014-01-01 00:00:00' and '2022-05-15 23:00:00'"
cursor.execute(query)
db_export = cursor.fetchall()

tp=pd.DataFrame(db_export)
#db_result_df = db_result_df.drop([db_result_df.columns[0]], axis=1) # 중복 index열 삭제

tp.index=tp['DATETIME']
tp.set_index('DATETIME', inplace=True)
tp.plot()
plt.show()

# %%
# https://blog.naver.com/chromatic_365/222657670527
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pymysql
import matplotlib as mpl

# mysql db 연동
db = pymysql.connect(host='127.0.0.1',password='gkftndlTek!!',user='root',db='tp',charset='utf8', 
    cursorclass=pymysql.cursors.DictCursor)

cursor = db.cursor()

query = "select DATETIME, P1 from wholeData where DATETIME between '2014-01-01 00:00:00' and '2022-05-15 23:00:00'"
cursor.execute(query)
db_export = cursor.fetchall()

tp=pd.DataFrame(db_export)
#db_result_df = db_result_df.drop([db_result_df.columns[0]], axis=1) # 중복 index열 삭제

tp.index=tp['DATETIME']
tp.set_index('DATETIME', inplace=True)
tp.plot()
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# (AR=2, 차분=1, MA=2) 파라미터로 ARIMA 모델을 학습합니다.
model = ARIMA(tp.FM.values, order=(2,1,2))

#trend : constant를 가지고 있는지, c - constant / nc - no constant
#disp : 수렴 정보를 나타냄
model_fit = model.fit(trend='c', full_output=True, disp=True)
print(model_fit.summary())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       2 import statsmodels.api as sm
#       4 # (AR=2, 차분=1, MA=2) 파라미터로 ARIMA 모델을 학습합니다.
# ----> 5 model = ARIMA(tp.FM.values, order=(2,1,2))
#       7 #trend : constant를 가지고 있는지, c - constant / nc - no constant
#       8 #disp : 수렴 정보를 나타냄
#       9 model_fit = model.fit(trend='c', full_output=True, disp=True)
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.
